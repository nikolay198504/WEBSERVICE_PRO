# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from chunks import Chunk

chunk = Chunk()
query = 'Какие исключения предусмотрены в договоре страхования ответственности аэропортов?'

async def main():
    result = await chunk.get_answer(query)
    print(result)

asyncio.run(main())
# Out:
#             В договоре страхования ответственности аэропортов предусмотрены следующие исключения:
#
# 1. Любая ответственность доверительного характера.
# 2. Неэффективность, то есть исключения (b) и (с) Раздела 3 стандартной формы полиса страхования ответственности владельцев и операторов аэропортов Ariel или Исключение (D), примененное к покрытию А и В формы полиса S.B.A.C. MW0500-98.
# 3. Риски шума и загрязнений (оговорка AVN46B или ее эквивалент).
# 4. Военные и сопутствующие им риски (оговорка AVN48B или ее эквивалент).
# 5. Оговорка об исключении ядерных рисков (AVN38B или AVN71).
# 6. Владение гостиницами, курортами, клубами, спортивными комплексами.
# 7. Ответственность туроператоров/туристических агентов, за исключением ответственности в части Договора о воздушной перевозке.
# ...
